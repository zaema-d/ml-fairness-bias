# %%
import sys
sys.path.append('..')
from src.data_loading import load_german, load_taiwan, load_folktables
from src.pipeline import run_subset_experiment
# Out:
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'fairlearn': ExponentiatedGradientReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'
# WARNING:root:No module named 'fairlearn': GridSearchReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'
# WARNING:root:No module named 'inFairness': SenSeI and SenSR will be unavailable. To install, run:
# pip install 'aif360[inFairness]'
# WARNING:root:No module named 'fairlearn': GridSearchReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'

# %%
german = load_german()
results_german_subsets = run_subset_experiment(german, 'sex')
print(results_german_subsets)
results_german_subsets.to_csv('../results/subset_german.csv')
# Out:
#                                        accuracy  stat_parity_diff  \
# training_subset   model
# privileged_only   Logistic Regression  0.756667         -0.086146
#                   Decision Tree        0.686667          0.002943
#                   Random Forest        0.766667         -0.030220
#                   XGBoost              0.750000         -0.013540
# unprivileged_only Logistic Regression  0.736667         -0.052983
#                   Decision Tree        0.666667          0.051805
#                   Random Forest        0.760000         -0.055926
#                   XGBoost              0.756667          0.036499
# combined          Logistic Regression  0.753333         -0.221350
#                   Decision Tree        0.720000         -0.103414
#                   Random Forest        0.780000         -0.082221
#                   XGBoost              0.776667         -0.042975
#
#                                        equal_opp_diff  disparate_impact  \
# ...

# %%
taiwan = load_taiwan()
results_taiwan_subsets = run_subset_experiment(taiwan, 'SEX')
print(results_taiwan_subsets)
results_taiwan_subsets.to_csv('../results/subset_taiwan.csv')
# Out:
#                                        accuracy  stat_parity_diff  \
# training_subset   model
# privileged_only   Logistic Regression  0.807778          0.020031
#                   Decision Tree        0.711667          0.025351
#                   Random Forest        0.802111          0.025666
#                   XGBoost              0.795889          0.029372
# unprivileged_only Logistic Regression  0.806778          0.018726
#                   Decision Tree        0.729889          0.001713
#                   Random Forest        0.812889          0.029085
#                   XGBoost              0.805444          0.024077
# combined          Logistic Regression  0.807444          0.034567
#                   Decision Tree        0.724667          0.035799
#                   Random Forest        0.810556          0.034832
#                   XGBoost              0.810111          0.040660
#
#                                        equal_opp_diff  disparate_impact  \
# ...

# %%
folktables_data = load_folktables()
results_folktables_subsets = run_subset_experiment(folktables_data, 'SEX')
print(results_folktables_subsets)
results_folktables_subsets.to_csv('../results/subset_folktables.csv')
# Out:
#                                        accuracy  stat_parity_diff  \
# training_subset   model
# privileged_only   Logistic Regression  0.758214          0.053109
#                   Decision Tree        0.765201          0.017721
#                   Random Forest        0.795329          0.013452
#                   XGBoost              0.815084          0.012629
# unprivileged_only Logistic Regression  0.758892          0.030679
#                   Decision Tree        0.741927          0.004710
#                   Random Forest        0.772293          0.009201
#                   XGBoost              0.806751          0.004418
# combined          Logistic Regression  0.770075         -0.090799
#                   Decision Tree        0.768201         -0.070698
#                   Random Forest        0.797635         -0.069288
#                   XGBoost              0.822211         -0.049221
#
#                                        equal_opp_diff  disparate_impact  \
# ...
